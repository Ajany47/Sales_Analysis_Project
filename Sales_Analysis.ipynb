# %%
import pandas as pd

# %%
filename = "C:/Users/bunma/OneDrive/Desktop/DataSet/New folder (7)/sales_data.csv"
df = pd.read_csv(filename)

# %%
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   object
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# ...

# %%
df.isnull().sum()
# Out:
# Product_ID              0
# Sale_Date               0
# Sales_Rep               0
# Region                  0
# Sales_Amount            0
# Quantity_Sold           0
# Product_Category        0
# Unit_Cost               0
# Unit_Price              0
# Customer_Type           0
# Discount                0
# Payment_Method          0
# Sales_Channel           0
# Region_and_Sales_Rep    0
# dtype: int64

# %%
df.describe()
# Out:
#         Product_ID  Sales_Amount  Quantity_Sold    Unit_Cost   Unit_Price  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          Discount
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df.dtypes)
# Out:
# Product_ID                int64
# Sale_Date                object
# Sales_Rep                object
# Region                   object
# Sales_Amount            float64
# Quantity_Sold             int64
# Product_Category         object
# Unit_Cost               float64
# Unit_Price              float64
# Customer_Type            object
# Discount                float64
# Payment_Method           object
# Sales_Channel            object
# Region_and_Sales_Rep     object
# dtype: object

# %%
df['Sale_Date'] = pd.to_datetime(df['Sale_Date']) # To convert the Sale_Date from object to datetime
-

# %%
print(df['Sale_Date'].dtype)
# Out:
# datetime64[ns]

# %%
print(df.dtypes)
# Out:
# Product_ID                       int64
# Sale_Date               datetime64[ns]
# Sales_Rep                       object
# Region                          object
# Sales_Amount                   float64
# Quantity_Sold                    int64
# Product_Category                object
# Unit_Cost                      float64
# Unit_Price                     float64
# Customer_Type                   object
# Discount                       float64
# Payment_Method                  object
# Sales_Channel                   object
# Region_and_Sales_Rep            object
# dtype: object

# %%
# To analyse the sales trend over time

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#sum of all the values across all  columns
df.sum()
# Out:
# C:\Users\bunma\AppData\Local\Temp\ipykernel_15264\3190118872.py:2: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()
# Product_ID                                                        1050128
# Sales_Rep               BobBobDavidBobCharlieCharlieBobEveDavidCharlie...
# Region                  NorthWestSouthSouthEastWestWestSouthSouthWestN...
# Sales_Amount                                                   5019265.23
# Quantity_Sold                                                       25355
# Product_Category        FurnitureFurnitureFoodClothingElectronicsFoodF...
# Unit_Cost                                                      2475304.55
# Unit_Price                                                     2728440.12
# ...

# %%
# Group sales by date
daily_sales = df.groupby('Sale_Date')['Sales_Amount'].sum()

# %%
daily_sales
# Out:
# Sale_Date
# 2023-01-01    14141.12
# 2023-01-02     6452.79
# 2023-01-03    21319.08
# 2023-01-04    30175.06
# 2023-01-05    16708.75
#                 ...
# 2023-12-28     7976.44
# 2023-12-29    20842.53
# 2023-12-30    26107.95
# 2023-12-31    28608.37
# 2024-01-01    19328.01
# Name: Sales_Amount, Length: 340, dtype: float64

# %%
# To find the date with the highest dailysales

# %%
max_sales_date = daily_sales.idxmax()

# %%
max_sales_date
# Out:
# Timestamp('2023-10-20 00:00:00')

# %%
# To find the highest sales amount

# %%
max_sales_value = daily_sales.max()

# %%
max_sales_value
# Out:
# 51695.71

# %%
print(f"Highest Sales Date: {max_sales_date}")
print(f"Highest Sales Amount: {max_sales_value}")
# Out:
# Highest Sales Date: 2023-10-20 00:00:00
# Highest Sales Amount: 51695.71

# %%
# Plot sales trend over time
plt.figure(figsize=(12, 6))
plt.plot(daily_sales, marker='o', linestyle='-')
plt.title('Daily Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# To analyse monthly sales trend, we need to extract year and month format.
df['YearMonth'] = df['Sale_Date'].dt.to_period('M')

# %%
df['YearMonth']
# Out:
# 0      2023-02
# 1      2023-04
# 2      2023-09
# 3      2023-08
# 4      2023-03
#         ...
# 995    2023-04
# 996    2023-09
# 997    2023-04
# 998    2023-12
# 999    2023-08
# Name: YearMonth, Length: 1000, dtype: period[M]

# %%
monthly_sales = df.groupby('YearMonth')['Sales_Amount'].sum()

# %%
monthly_sales
# Out:
# YearMonth
# 2023-01    476092.36
# 2023-02    368919.36
# 2023-03    402638.77
# 2023-04    438992.61
# 2023-05    389078.76
# 2023-06    418458.34
# 2023-07    374242.88
# 2023-08    443171.28
# 2023-09    367837.60
# 2023-10    460378.78
# 2023-11    467482.90
# 2023-12    392643.58
# 2024-01     19328.01
# Freq: M, Name: Sales_Amount, dtype: float64

# %%
df['YearMonth'] = df['Sale_Date'].dt.to_period('M')  # Convert to Year-Month format

# Group by Year-Month
monthly_sales = df.groupby('YearMonth')['Sales_Amount'].sum()

# Convert Period to string for plotting
monthly_sales.index = monthly_sales.index.astype(str)

# Plot Monthly Sales Trend
plt.figure(figsize=(12, 6))
plt.plot(monthly_sales, marker='o', linestyle='-')
plt.title('Monthly Sales Trend')
plt.xlabel('Year-Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# To show top 5 Highest Sales Days

# %%
top_5_sales_days = daily_sales.sort_values(ascending=False).head(5)
print(top_5_sales_days)
# Out:
# Sale_Date
# 2023-10-20    51695.71
# 2023-10-15    43628.04
# 2023-01-12    43522.74
# 2023-10-16    41683.41
# 2023-11-24    40711.70
# Name: Sales_Amount, dtype: float64

# %%
# Filter data for the highest sales date
highest_sales_df = df[df['Sale_Date'] == max_sales_date]

# Summarize key factors
top_products = highest_sales_df.groupby('Product_Category')['Sales_Amount'].sum().sort_values(ascending=False)
top_regions = highest_sales_df.groupby('Region')['Sales_Amount'].sum().sort_values(ascending=False)
top_sales_reps = highest_sales_df.groupby('Sales_Rep')['Sales_Amount'].sum().sort_values(ascending=False)
top_customers = highest_sales_df.groupby('Customer_Type')['Sales_Amount'].sum().sort_values(ascending=False)

# Display results
print("\nTop Selling Products on the Highest Sales Day:\n", top_products.head(5))
print("\nTop Selling Regions on the Highest Sales Day:\n", top_regions.head(5))
print("\nTop Sales Reps on the Highest Sales Day:\n", top_sales_reps.head(5))
print("\nTop Customer Types on the Highest Sales Day:\n", top_customers.head(5))
# Out:
# Top Selling Products on the Highest Sales Day:
#  Product_Category
# Clothing       27253.29
# Electronics    15784.34
# Food            5081.01
# Furniture       3577.07
# Name: Sales_Amount, dtype: float64
#
# Top Selling Regions on the Highest Sales Day:
#  Region
# South    33257.07
# North    12342.82
# East      6095.82
# Name: Sales_Amount, dtype: float64
#
# Top Sales Reps on the Highest Sales Day:
#  Sales_Rep
# David      36926.18
# Alice       9688.52
# Charlie     5081.01
# Name: Sales_Amount, dtype: float64
#
# Top Customer Types on the Highest Sales Day:
#  Customer_Type
# Returning    35507.25
# New          16188.46
# Name: Sales_Amount, dtype: float64

# %%
# To analyse discounts and sales channel

# %%
# Check total discount impact
total_discount = highest_sales_df['Discount'].sum()

# Sales by Payment Method
payment_methods = highest_sales_df.groupby('Payment_Method')['Sales_Amount'].sum().sort_values(ascending=False)

# Sales by Sales Channel
sales_channels = highest_sales_df.groupby('Sales_Channel')['Sales_Amount'].sum().sort_values(ascending=False)

# Display results
print(f"\nTotal Discounts Given: {total_discount}")
print("\nSales by Payment Method:\n", payment_methods)
print("\nSales by Sales Channel:\n", sales_channels)
# Out:
# Total Discounts Given: 1.17
#
# Sales by Payment Method:
#  Payment_Method
# Bank Transfer    22628.75
# Credit Card      15515.77
# Cash             13551.19
# Name: Sales_Amount, dtype: float64
#
# Sales by Sales Channel:
#  Sales_Channel
# Retail    45195.77
# Online     6499.94
# Name: Sales_Amount, dtype: float64

# %%
# to visualize the top contributors, we can use bar charts:

# %%
import seaborn as sns

plt.figure(figsize=(10, 5))
sns.barplot(x=top_products.index[:5], y=top_products.values[:5])
plt.title("Top Selling Products on Highest Sales Day")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
# Top selling regions
plt.figure(figsize=(10, 5))
sns.barplot(x=top_regions.index[:5], y=top_regions.values[:5])
plt.title("Top Selling Regions on Highest Sales Day")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)  
plt.show()

# %%
# Top Sales rep
plt.figure(figsize=(10, 5))
sns.barplot(x=top_sales_reps.index[:5], y=top_sales_reps.values[:5])
plt.title("Top Sales Reps on Highest Sales Day")
plt.xlabel("Sales Rep")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)  
plt.show()

# %%
# customer type contribution
plt.figure(figsize=(8, 4))
sns.barplot(x=top_customers.index, y=top_customers.values)
plt.title("Customer Type Contribution to Sales")
plt.xlabel("Customer Type")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.show()

# %%
cd "C:/Users/bunma/OneDrive/Desktop/DataSet/New folder (7)/"
# Out:
# C:\Users\bunma\OneDrive\Desktop\DataSet\New folder (7)

# %%
import os
print(os.getcwd())  # Shows the current working directory
# Out:
# C:\Users\bunma
